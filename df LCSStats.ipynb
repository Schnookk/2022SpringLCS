# %%
import pandas as pd

# %%
df = pd.read_csv('dfLCSSpring2022.csv') #read csv

# %%
df.columns #list all column names
# Out:
# Index(['date', 'participantid', 'side', 'position', 'playername', 'teamname',
#        'champion', 'result', 'kills', 'deaths', 'assists', 'teamkills',
#        'teamdeaths', 'dragons', 'opp_dragons', 'turretplates',
#        'opp_turretplates', 'dpm', 'damageshare', 'cspm', 'golddiffat10'],
#       dtype='object')

# %%
df.head() #show first 5 rows
# Out:
#                   date  participantid  side position playername teamname  \
# 0  2022-01-14 21:26:31              1  Blue      top      V1per      TSM
# 1  2022-01-14 21:26:31              2  Blue      jng      Hyper      TSM
# 2  2022-01-14 21:26:31              3  Blue      mid   Takeover      TSM
# 3  2022-01-14 21:26:31              4  Blue      bot   Instinct      TSM
# 4  2022-01-14 21:26:31              5  Blue      sup     Yursan      TSM
#
#    champion  result  kills  deaths  ...  teamkills  teamdeaths  dragons  \
# 0     Vayne       0      0       5  ...          1          15      NaN
# 1  Xin Zhao       0      0       2  ...          1          15      NaN
# 2   LeBlanc       0      0       3  ...          1          15      NaN
# 3  Aphelios       0      1       2  ...          1          15      NaN
# 4  Nautilus       0      0       3  ...          1          15      NaN
#
#    opp_dragons  turretplates  opp_turretplates       dpm  damageshare    cspm  \
# ...

# %%
df.tail() #show last 5 rows
# Out:
#                      date  participantid  side position playername  \
# 1915  2022-04-24 21:14:20              8   Red      mid   jojopyun
# 1916  2022-04-24 21:14:20              9   Red      bot      Danny
# 1917  2022-04-24 21:14:20             10   Red      sup     Vulcan
# 1918  2022-04-24 21:14:20            100  Blue     team        NaN
# 1919  2022-04-24 21:14:20            200   Red     team        NaN
#
#            teamname  champion  result  kills  deaths  ...  teamkills  \
# 1915  Evil Geniuses    Viktor       1      4       1  ...         17
# 1916  Evil Geniuses     Xayah       1      9       1  ...         17
# 1917  Evil Geniuses  Nautilus       1      2       4  ...         17
# 1918    100 Thieves       NaN       0      8      17  ...          8
# 1919  Evil Geniuses       NaN       1     17       8  ...         17
#
#       teamdeaths  dragons  opp_dragons  turretplates  opp_turretplates  \
# 1915           8      NaN          NaN           NaN               NaN
# ...

# %%
df[:10] #display first 10 rows, first game of the season
# Out:
#                   date  participantid  side position playername     teamname  \
# 0  2022-01-14 21:26:31              1  Blue      top      V1per          TSM
# 1  2022-01-14 21:26:31              2  Blue      jng      Hyper          TSM
# 2  2022-01-14 21:26:31              3  Blue      mid   Takeover          TSM
# 3  2022-01-14 21:26:31              4  Blue      bot   Instinct          TSM
# 4  2022-01-14 21:26:31              5  Blue      sup     Yursan          TSM
# 5  2022-01-14 21:26:31              6   Red      top    Ssumday  100 Thieves
# 6  2022-01-14 21:26:31              7   Red      jng     Closer  100 Thieves
# 7  2022-01-14 21:26:31              8   Red      mid  Abbedagge  100 Thieves
# 8  2022-01-14 21:26:31              9   Red      bot        FBI  100 Thieves
# 9  2022-01-14 21:26:31             10   Red      sup       huhi  100 Thieves
#
#    champion  result  kills  deaths  ...  teamkills  teamdeaths  dragons  \
# ...

# %%
df[-10:] #display last 10 rows, last game of the season
# Out:
#                      date  participantid  side position playername  \
# 1910  2022-04-24 21:14:20              3  Blue      mid  Abbedagge
# 1911  2022-04-24 21:14:20              4  Blue      bot        FBI
# 1912  2022-04-24 21:14:20              5  Blue      sup       huhi
# 1913  2022-04-24 21:14:20              6   Red      top     Impact
# 1914  2022-04-24 21:14:20              7   Red      jng   Inspired
# 1915  2022-04-24 21:14:20              8   Red      mid   jojopyun
# 1916  2022-04-24 21:14:20              9   Red      bot      Danny
# 1917  2022-04-24 21:14:20             10   Red      sup     Vulcan
# 1918  2022-04-24 21:14:20            100  Blue     team        NaN
# 1919  2022-04-24 21:14:20            200   Red     team        NaN
#
#            teamname   champion  result  kills  deaths  ...  teamkills  \
# 1910    100 Thieves        Vex       0      2       3  ...          8
# 1911    100 Thieves       Zeri       0      3       5  ...          8
# ...

# %%
df.iloc[1200,4] #display specific field based on coordinates
# Out:
# 'Kumo'

# %%
df['KDA'] = (df['kills'] + df['assists']) / df['deaths']

# %%
df_teams = df[df['participantid'] >= 100]
df_teams.head()
# Out:
#                    date  participantid  side position playername  \
# 10  2022-01-14 21:26:31            100  Blue     team        NaN
# 11  2022-01-14 21:26:31            200   Red     team        NaN
# 22  2022-01-14 23:05:35            100  Blue     team        NaN
# 23  2022-01-14 23:05:35            200   Red     team        NaN
# 34   2022-01-15 0:00:36            100  Blue     team        NaN
#
#             teamname champion  result  kills  deaths  ...  teamdeaths  \
# 10               TSM      NaN       0      1      15  ...          15
# 11       100 Thieves      NaN       1     15       1  ...           1
# 22            Cloud9      NaN       1     19       9  ...           9
# 23  Golden Guardians      NaN       0      9      19  ...          19
# 34          FlyQuest      NaN       0     15      21  ...          21
#
#     dragons  opp_dragons  turretplates  opp_turretplates        dpm  \
# 10      0.0          4.0           1.0               9.0   936.6771
# ...

# %%
df_players = df[df['participantid'] < 100]
df_players[:11]
# Out:
#                    date  participantid  side position playername     teamname  \
# 0   2022-01-14 21:26:31              1  Blue      top      V1per          TSM
# 1   2022-01-14 21:26:31              2  Blue      jng      Hyper          TSM
# 2   2022-01-14 21:26:31              3  Blue      mid   Takeover          TSM
# 3   2022-01-14 21:26:31              4  Blue      bot   Instinct          TSM
# 4   2022-01-14 21:26:31              5  Blue      sup     Yursan          TSM
# 5   2022-01-14 21:26:31              6   Red      top    Ssumday  100 Thieves
# 6   2022-01-14 21:26:31              7   Red      jng     Closer  100 Thieves
# 7   2022-01-14 21:26:31              8   Red      mid  Abbedagge  100 Thieves
# 8   2022-01-14 21:26:31              9   Red      bot        FBI  100 Thieves
# 9   2022-01-14 21:26:31             10   Red      sup       huhi  100 Thieves
# 12  2022-01-14 23:05:35              1  Blue      top    Darshan       Cloud9
#
# ...

# %%
df_teams.sort_values(by=['KDA'], ascending=False)
# Out:
#                      date  participantid  side position playername  \
# 11    2022-01-14 21:26:31            200   Red     team        NaN
# 1763  2022-04-16 20:06:15            200   Red     team        NaN
# 274   2022-01-22 23:12:36            100  Blue     team        NaN
# 1786  2022-04-16 22:05:57            100  Blue     team        NaN
# 526    2022-02-06 1:52:58            100  Blue     team        NaN
# ...                   ...            ...   ...      ...        ...
# 862    2022-02-26 0:27:00            100  Blue     team        NaN
# 947    2022-02-27 2:35:00            200   Red     team        NaN
# 1762  2022-04-16 20:06:15            100  Blue     team        NaN
# 10    2022-01-14 21:26:31            100  Blue     team        NaN
# 923    2022-02-27 0:40:00            200   Red     team        NaN
#
#               teamname champion  result  kills  deaths  ...  teamdeaths  \
# 11         100 Thieves      NaN       1     15       1  ...           1
# ...

# %%
df_Bjergsen = df[df['playername'] == 'Bjergsen'] #new dataframe for analyzing Bjergsen's stats
df_Bjergsen #display Bjergsen dataframe
# Out:
#                      date  participantid  side position playername  \
# 67    2022-01-15 20:52:15              8   Red      mid   Bjergsen
# 86    2022-01-15 22:50:00              3  Blue      mid   Bjergsen
# 134   2022-01-16 21:11:18              3  Blue      mid   Bjergsen
# 211    2022-01-22 0:06:11              8   Red      mid   Bjergsen
# 266   2022-01-22 23:12:36              3  Blue      mid   Bjergsen
# 283    2022-01-23 0:16:32              8   Red      mid   Bjergsen
# 350   2022-01-28 21:53:04              3  Blue      mid   Bjergsen
# 362   2022-01-28 23:22:12              3  Blue      mid   Bjergsen
# 379    2022-01-29 0:17:44              8   Red      mid   Bjergsen
# 391    2022-01-29 1:13:24              8   Red      mid   Bjergsen
# 439   2022-01-30 18:42:24              8   Red      mid   Bjergsen
# 451   2022-01-30 21:02:22              8   Red      mid   Bjergsen
# 458   2022-01-30 21:59:02              3  Blue      mid   Bjergsen
# ...

# %%
df_team_kda_wins = df_teams.groupby('teamname').agg({'result':'sum', 'KDA':'mean'}).rename(columns={'result':'Wins'}) #new dataframe for team kda, grouped by team name
df_team_kda_wins2 = df_team_kda_wins.sort_values(by='Wins', ascending=False).round(2) #sort dataframe descending, round for readability 
df_team_kda_wins2
# Out:
#                       Wins   KDA
# teamname
# Evil Geniuses           33  6.59
# Team Liquid             30  6.97
# 100 Thieves             21  7.85
# Cloud9                  21  5.08
# FlyQuest                13  3.62
# Dignitas                12  4.79
# Golden Guardians        10  3.60
# Counter Logic Gaming     9  3.32
# TSM                      6  2.63
# Immortals                5  3.09

# %%
df_team_kda_wins2.plot()
# Out:
# <AxesSubplot:xlabel='teamname'>

# %%
df_players_best = df_players.groupby('playername').agg({'cspm':'mean', 'kills':'mean'}).rename(columns={'cspm':'CS/min', 'kills':'Avg Kills'}).sort_values(by='CS/min', ascending=False).round(2) #new dataframe for player stats
df_players_best[:15]
# Out:
#             CS/min  Avg Kills
# playername
# Danny         9.98       5.16
# Hans sama     9.87       3.93
# Keaiduo       9.75       1.67
# Stixxay       9.73       2.17
# Neo           9.71       3.64
# Johnsun       9.64       3.77
# Luger         9.58       3.12
# Berserker     9.46       3.37
# Blue          9.31       2.79
# Tactical      9.29       4.22
# Takeover      9.14       2.00
# FBI           9.14       3.66
# Zven          9.13       3.70
# Bradley       9.05       7.00
# Fudge         8.98       3.54

# %%
df_players_best[:45].plot()
# Out:
# <AxesSubplot:xlabel='playername'>
